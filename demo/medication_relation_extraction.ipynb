# %% [markdown]
# # Drug, Strength, and Frequency Extraction
# #### This notebook demos named entity recognition (NER) and relation extraction (RE) tasks with the llm-ie package.

# %%
from llm_ie.engines import OllamaInferenceEngine
from llm_ie.extractors import SentenceFrameExtractor, MultiClassRelationExtractor
from llm_ie.data_types import LLMInformationExtractionDocument

# %% [markdown]
# We load a synthesized medical note generated by ChatGPT. In this demo, we will use this medical note to show NER and RE workflow.

# %%
# Load synthesized medical note
with open("./document/synthesized_note.txt", 'r') as f:
    note_text = f.read()

print(note_text)
# Out:
# ### Discharge Summary Note
#
# **Patient Name:** John Doe
# **Medical Record Number:** 12345678
# **Date of Birth:** January 15, 1975
# **Date of Admission:** July 20, 2024
# **Date of Discharge:** July 27, 2024
#
# **Attending Physician:** Dr. Jane Smith, MD
# **Consulting Physicians:** Dr. Emily Brown, MD (Cardiology), Dr. Michael Green, MD (Pulmonology)
#
# #### Reason for Admission
# John Doe, a 49-year-old male, was admitted to the hospital with complaints of chest pain, shortness of breath, and dizziness. The patient has a history of hypertension, hyperlipidemia, and Type 2 diabetes mellitus.
#
# #### History of Present Illness
# The patient reported that the chest pain started two days prior to admission. The pain was described as a pressure-like sensation in the central chest, radiating to the left arm and jaw. He also experienced dyspnea on exertion and occasional palpitations. The patient denied any recent upper respiratory infection, cough, or fever.
#
# #### Past Medical History
# - Hypertension (diagnosed in 2010)
# - Hyperlipidemia (diagnosed in 2015)
# - Type 2 Diabetes Mellitus (diagnosed in 2018)
#
# #### Social History
# - Former smoker (quit in 2010)
# - Occasional alcohol consumption
# - Works as an accountant
# - Married with two children
#
# #### Family History
# - Father: myocardial infarction at age 55
# - Mother: Type 2 diabetes mellitus
#
# #### Physical Examination
# - **Vital Signs:** Blood pressure 160/95 mmHg, heart rate 88 bpm, respiratory rate 20 breaths/min, temperature 98.6°F, oxygen saturation 96% on room air.
# - **General:** Alert and oriented, in mild distress.
# - **Cardiovascular:** Regular rhythm, no murmurs, rubs, or gallops. Jugular venous pressure not elevated.
# - **Respiratory:** Clear to auscultation bilaterally, no wheezes, rales, or rhonchi.
# - **Abdomen:** Soft, non-tender, no hepatosplenomegaly.
# - **Extremities:** No edema, pulses 2+ bilaterally.
#
# #### Laboratory and Diagnostic Tests
# - **EKG:** ST-segment depression in leads V4-V6.
# - **Troponin I:** Elevated at 0.15 ng/mL (normal <0.04 ng/mL).
# - **Chest X-ray:** No acute infiltrates, normal cardiac silhouette.
# - **Echocardiogram:** Mild left ventricular hypertrophy, ejection fraction 55%.
# - **CBC:** WBC 8.5 x 10^3/uL, Hgb 13.5 g/dL, Platelets 250 x 10^3/uL.
# - **CMP:** Na 138 mmol/L, K 4.0 mmol/L, BUN 15 mg/dL, Creatinine 0.9 mg/dL, Glucose 180 mg/dL, HbA1c 7.8%.
#
# #### Hospital Course
# John Doe was diagnosed with acute coronary syndrome (ACS). He was started on dual antiplatelet therapy with aspirin and clopidogrel, along with high-dose atorvastatin, and a beta-blocker. A cardiology consultation was obtained, and the patient underwent coronary angiography, which revealed a 70% stenosis in the left anterior descending artery. A drug-eluting stent was placed successfully.
#
# Post-procedure, the patient was monitored in the coronary care unit. He remained hemodynamically stable, with no recurrent chest pain. He was gradually advanced to a regular cardiac diet and was ambulating without difficulty by day three of hospitalization. Diabetes management was optimized with the addition of metformin, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular physical activity, and monitor his blood glucose levels. He was instructed to avoid smoking and limit alcohol intake. Follow-up appointments were scheduled with his primary care physician, cardiologist, and endocrinologist.
#
# The patient was educated on the signs and symptoms of recurrent chest pain and instructed to seek immediate medical attention if they occur. He was provided with a prescription for a nitroglycerin tablet to use as needed for chest pain.
#
# #### Follow-Up Appointments
# - Primary Care Physician: August 3, 2024
# - Cardiology: August 10, 2024
# - Endocrinology: August 17, 2024
#
# **Discharge Summary Prepared by:**
# Dr. Jane Smith, MD
# July 27, 2024

# %% [markdown]
# We start with defining a LLM inference engine and LLM. In this demo, we use Ollama to run Llama 3.1 70B.

# %%
# Define a LLM inference engine
llm = OllamaInferenceEngine(model_name="llama3.1:70b-instruct-q8_0", keep_alive=3600)

# %% [markdown]
# ### Frame extraction (NER)
#
# We write a prompt template for NER. This can be done manually or through the built-in ```PromptEditor``` (see GitHub main page).

# %%
prompt_template = """
# Task description
The clinical note below contains information about medications prescribed to a patient. Your task is to extract medication-related information from a given sentence (provided by user at a time). Specifically, you need to identify mentions of medication names, strengths, and frequencies.

# Schema definition
Your output should contain: 
    "entity_text" which is the exact mention of the entity,
    "entity_type" which is one of the "Medication", "Strength", or "Frequency".

# Output format definition
Your output should follow JSON format. If there are medication-related mentions:
[
    {"entity_text": "<Medication name>", "entity_type": "Medication"}, 
    {"entity_text": "<Strength mention>", "entity_type": "Strength"},
    {"entity_text": "<Frequency mention>", "entity_type": "Frequency"}
]
If there is no medication-related information in the given sentence, just output an empty list:
[]

# Additional hints
Your output should be 100% based on the provided content. DO NOT output fake information.

# Input placeholder
Below is the clinical note for your reference. I will feed you with sentences from it one by one.
{{input}}
"""

# %% [markdown]
# Now, we define an extractor to perform frame extraction. Note this code block will take a few minutes to run, depending on your GPU.

# %%
# Define extractor
extractor = SentenceFrameExtractor(llm, prompt_template)

# Extract
frames =  extractor.extract_frames(note_text, entity_key="entity_text", stream=True)
# Out:
# Sentence:
# ### Discharge Summary Note
#
# **Patient Name:** John Doe
# **Medical Record Number:** 12345678
# **Date of Birth:** January 15, 1975
# **Date of Admission:** July 20, 2024
# **Date of Discharge:** July 27, 2024
#
# **Attending Physician:** Dr.
#
# Extraction:
# []
#
#
#
# Sentence:
# Jane Smith, MD
# **Consulting Physicians:** Dr.
#
# Extraction:
# []
#
#
#
# Sentence:
# Emily Brown, MD (Cardiology), Dr.
#
# Extraction:
# []
#
#
#
# Sentence:
# Michael Green, MD (Pulmonology)
#
# #### Reason for Admission
# John Doe, a 49-year-old male, was admitted to the hospital with complaints of chest pain, shortness of breath, and dizziness.
#
# Extraction:
# []
#
#
#
# Sentence:
# The patient has a history of hypertension, hyperlipidemia, and Type 2 diabetes mellitus.
#
# Extraction:
# []
#
#
#
# Sentence:
# #### History of Present Illness
# The patient reported that the chest pain started two days prior to admission.
#
# Extraction:
# []
#
#
#
# Sentence:
# The pain was described as a pressure-like sensation in the central chest, radiating to the left arm and jaw.
#
# Extraction:
# []
#
#
#
# Sentence:
# He also experienced dyspnea on exertion and occasional palpitations.
#
# Extraction:
# []
#
#
#
# Sentence:
# The patient denied any recent upper respiratory infection, cough, or fever.
#
# Extraction:
# []
#
#
#
# Sentence:
# #### Past Medical History
# - Hypertension (diagnosed in 2010)
# - Hyperlipidemia (diagnosed in 2015)
# - Type 2 Diabetes Mellitus (diagnosed in 2018)
#
# #### Social History
# - Former smoker (quit in 2010)
# - Occasional alcohol consumption
# - Works as an accountant
# - Married with two children
#
# #### Family History
# - Father: myocardial infarction at age 55
# - Mother: Type 2 diabetes mellitus
#
# #### Physical Examination
# - **Vital Signs:** Blood pressure 160/95 mmHg, heart rate 88 bpm, respiratory rate 20 breaths/min, temperature 98.6°F, oxygen saturation 96% on room air.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **General:** Alert and oriented, in mild distress.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Cardiovascular:** Regular rhythm, no murmurs, rubs, or gallops.
#
# Extraction:
# []
#
#
#
# Sentence:
# Jugular venous pressure not elevated.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Respiratory:** Clear to auscultation bilaterally, no wheezes, rales, or rhonchi.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Abdomen:** Soft, non-tender, no hepatosplenomegaly.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Extremities:** No edema, pulses 2+ bilaterally.
#
# Extraction:
# []
#
#
#
# Sentence:
# #### Laboratory and Diagnostic Tests
# - **EKG:** ST-segment depression in leads V4-V6.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Troponin I:** Elevated at 0.15 ng/mL (normal <0.04 ng/mL).
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Chest X-ray:** No acute infiltrates, normal cardiac silhouette.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **Echocardiogram:** Mild left ventricular hypertrophy, ejection fraction 55%.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **CBC:** WBC 8.5 x 10^3/uL, Hgb 13.5 g/dL, Platelets 250 x 10^3/uL.
#
# Extraction:
# []
#
#
#
# Sentence:
# - **CMP:** Na 138 mmol/L, K 4.0 mmol/L, BUN 15 mg/dL, Creatinine 0.9 mg/dL, Glucose 180 mg/dL, HbA1c 7.8%.
#
# Extraction:
# []
#
#
#
# Sentence:
# #### Hospital Course
# John Doe was diagnosed with acute coronary syndrome (ACS).
#
# Extraction:
# []
#
#
#
# Sentence:
# He was started on dual antiplatelet therapy with aspirin and clopidogrel, along with high-dose atorvastatin, and a beta-blocker.
#
# Extraction:
# [
#   {"entity_text": "aspirin", "entity_type": "Medication"},
#   {"entity_text": "clopidogrel", "entity_type": "Medication"},
#   {"entity_text": "high-dose atorvastatin", "entity_type": "Strength"}
# ]
#
#
#
# Sentence:
# A cardiology consultation was obtained, and the patient underwent coronary angiography, which revealed a 70% stenosis in the left anterior descending artery.
#
# Extraction:
# []
#
#
#
# Sentence:
# A drug-eluting stent was placed successfully.
#
# Extraction:
# [
#   {"entity_text": "drug-eluting stent", "entity_type": "Medication"}
# ]
#
#
#
# Sentence:
# Post-procedure, the patient was monitored in the coronary care unit.
#
# Extraction:
# []
#
#
#
# Sentence:
# He remained hemodynamically stable, with no recurrent chest pain.
#
# Extraction:
# []
#
#
#
# Sentence:
# He was gradually advanced to a regular cardiac diet and was ambulating without difficulty by day three of hospitalization.
#
# Extraction:
# []
#
#
#
# Sentence:
# Diabetes management was optimized with the addition of metformin, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# Extraction:
# [
#   {"entity_text": "metformin", "entity_type": "Medication"}
# ]
#
#
#
# Sentence:
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular physical activity, and monitor his blood glucose levels.
#
# Extraction:
# [
#   {"entity_text": "Aspirin", "entity_type": "Medication"},
#   {"entity_text": "81 mg", "entity_type": "Strength"},
#   {"entity_text": "daily", "entity_type": "Frequency"},
#   {"entity_text": "Clopidogrel", "entity_type": "Medication"},
#   {"entity_text": "75 mg", "entity_type": "Strength"},
#   {"entity_text": "daily", "entity_type": "Frequency"},
#   {"entity_text": "Atorvastatin", "entity_type": "Medication"},
#   {"entity_text": "40 mg", "entity_type": "Strength"},
#   {"entity_text": "daily", "entity_type": "Frequency"},
#   {"entity_text": "Metoprolol", "entity_type": "Medication"},
#   {"entity_text": "50 mg", "entity_type": "Strength"},
#   {"entity_text": "twice daily", "entity_type": "Frequency"},
#   {"entity_text": "Lisinopril", "entity_type": "Medication"},
#   {"entity_text": "20 mg", "entity_type": "Strength"},
#   {"entity_text": "daily", "entity_type": "Frequency"},
#   {"entity_text": "Metformin", "entity_type": "Medication"},
#   {"entity_text": "1000 mg", "entity_type": "Strength"},
#   {"entity_text": "twice daily", "entity_type": "Frequency"}
# ]
#
#
#
# Sentence:
# He was instructed to avoid smoking and limit alcohol intake.
#
# Extraction:
# []
#
#
#
# Sentence:
# Follow-up appointments were scheduled with his primary care physician, cardiologist, and endocrinologist.
#
# Extraction:
# []
#
#
#
# Sentence:
# The patient was educated on the signs and symptoms of recurrent chest pain and instructed to seek immediate medical attention if they occur.
#
# Extraction:
# []
#
#
#
# Sentence:
# He was provided with a prescription for a nitroglycerin tablet to use as needed for chest pain.
#
# Extraction:
# [
#   {"entity_text": "nitroglycerin", "entity_type": "Medication"}
# ]
#
#
#
# Sentence:
# #### Follow-Up Appointments
# - Primary Care Physician: August 3, 2024
# - Cardiology: August 10, 2024
# - Endocrinology: August 17, 2024
#
# **Discharge Summary Prepared by:**
# Dr.
#
# Extraction:
# []
#
#
#
# Sentence:
# Jane Smith, MD
# July 27, 2024
#
# Extraction:
# []

# %% [markdown]
# The extractor outputs a list of frames (```LLMInformationExtractionFrame```). We can print them for inspection.

# %%
# Check extractions
for frame in frames:
    print(frame.to_dict())
# Out:
# {'frame_id': '0', 'start': 2482, 'end': 2489, 'entity_text': 'aspirin', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '1', 'start': 2494, 'end': 2505, 'entity_text': 'clopidogrel', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '2', 'start': 2518, 'end': 2540, 'entity_text': 'high-dose atorvastatin', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '3', 'start': 2722, 'end': 2740, 'entity_text': 'drug-eluting stent', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '4', 'start': 3080, 'end': 3089, 'entity_text': 'metformin', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '5', 'start': 3214, 'end': 3221, 'entity_text': 'Aspirin', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '6', 'start': 3222, 'end': 3227, 'entity_text': '81 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '7', 'start': 3228, 'end': 3233, 'entity_text': 'daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '8', 'start': 3236, 'end': 3247, 'entity_text': 'Clopidogrel', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '9', 'start': 3248, 'end': 3253, 'entity_text': '75 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '10', 'start': 3254, 'end': 3259, 'entity_text': 'daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '11', 'start': 3262, 'end': 3274, 'entity_text': 'Atorvastatin', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '12', 'start': 3275, 'end': 3280, 'entity_text': '40 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '13', 'start': 3281, 'end': 3286, 'entity_text': 'daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '14', 'start': 3289, 'end': 3299, 'entity_text': 'Metoprolol', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '15', 'start': 3300, 'end': 3305, 'entity_text': '50 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '16', 'start': 3306, 'end': 3317, 'entity_text': 'twice daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '17', 'start': 3320, 'end': 3330, 'entity_text': 'Lisinopril', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '18', 'start': 3331, 'end': 3336, 'entity_text': '20 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '19', 'start': 3337, 'end': 3342, 'entity_text': 'daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '20', 'start': 3345, 'end': 3354, 'entity_text': 'Metformin', 'attr': {'entity_type': 'Medication'}}
# {'frame_id': '21', 'start': 3355, 'end': 3362, 'entity_text': '1000 mg', 'attr': {'entity_type': 'Strength'}}
# {'frame_id': '22', 'start': 3363, 'end': 3374, 'entity_text': 'twice daily', 'attr': {'entity_type': 'Frequency'}}
# {'frame_id': '23', 'start': 3883, 'end': 3896, 'entity_text': 'nitroglycerin', 'attr': {'entity_type': 'Medication'}}

# %% [markdown]
# We define a document object to store the extracted frames. The ```add_frames()``` method will validate frames (check for duplicates), and assign automatic IDs.

# %%
# Define document
doc = LLMInformationExtractionDocument(doc_id="Meidcal note", text=note_text)

# Add frames to document
doc.add_frames(frames, valid_mode="span", create_id=True)

# %% [markdown]
# Inspect the document. Now the document holds the frames.

# %%
print(doc)
# Out:
# LLMInformationExtractionDocument(doc_id: "Meidcal note"
# text: "### Discharge Summary Note
#
# **Patient Name:** John Doe
# **Medical Record Number:** 12345678
# **Dat...",
# frames: 24
# relations: 0

# %% [markdown]
# ### Relation extractio (RE)
#
# Now that we have frames, we can extract relations between them. We write a prompt template for RE as below. This can be done manually or through the ```PromptEditor```.

# %%
re_prompt_template = """
# Task description
This is a multi-class relation extraction task. Given a region of interest (ROI) text and two frames from a medical note, classify the relation types between the two frames. 

# Schema definition
    Strength-Drug: this is a relationship between the drug strength and its name.
    Frequency-Drug: this is a relationship between a drug frequency and its name.

# Output format definition
    Choose one of the relation types listed below or choose "No Relation":
    {{pos_rel_types}}

    Your output should follow the JSON format:
    {"RelationType": "<relation type or No Relation>"}

    I am only interested in the content between []. Do not explain your answer. 

# Hints
    1. Your input always contains one medication entity and 1) one strength entity or 2) one frequency entity.
    2. Pay attention to the medication entity and see if the strength or frequency is for it.
    3. If the strength or frequency is for another medication, output "No Relation". 
    4. If the strength or frequency is for the same medication but at a different location (span), output "No Relation".

# Input placeholders
ROI Text with the two entities annotated with <entity_1> and <entity_2>:
"{{roi_text}}"

Entity 1 full information:
{{frame_1}}

Entity 2 full information:
{{frame_2}}
"""

# %% [markdown]
# To avoid checking all combinations of frame-pairs (which will consume a lot of computation), the RelationExtractors requires users to input a pre-processing function: given two frames, output the possible relation types between them.
#
# In the function ```possible_relation_types_func``` below, we set:
#   - if the two frames are > 500 characters apart, we assumes "No Relation"
#   - if the two frames are "Medication" and "Strength", the only possible relation types are "Strength-Drug" or "No Relation"
#   - if the two frames are "Medication" and "Frequency", the only possible relation types are "Frequency-Drug" or "No Relation"

# %%
from typing import List

def possible_relation_types_func(frame_1, frame_2) -> List[str]:
    # If the two frames are > 500 characters apart, we assume "No Relation"
    if abs(frame_1.start - frame_2.start) > 500:
        return []
    
    # If the two frames are "Medication" and "Strength", the only possible relation types are "Strength-Drug" or "No Relation"
    if (frame_1.attr["entity_type"] == "Medication" and frame_2.attr["entity_type"] == "Strength") or \
        (frame_2.attr["entity_type"] == "Medication" and frame_1.attr["entity_type"] == "Strength"):
        return ['Strength-Drug']
    
    # If the two frames are "Medication" and "Frequency", the only possible relation types are "Frequency-Drug" or "No Relation"
    if (frame_1.attr["entity_type"] == "Medication" and frame_2.attr["entity_type"] == "Frequency") or \
        (frame_2.attr["entity_type"] == "Medication" and frame_1.attr["entity_type"] == "Frequency"):
        return ['Frequency-Drug']

    return []

# %% [markdown]
# Now we can define a relation extractor to perform relation extraction. Note this code block can take a few minutes to run.

# %%
# Define relation extractor
relation_extractor = MultiClassRelationExtractor(llm, prompt_template=re_prompt_template, possible_relation_types_func=possible_relation_types_func)

# Extract multi-class relations
relations = relation_extractor.extract_relations(doc, stream=True)
# Out:
# ROI text:
# ... was diagnosed with acute coronary syndrome (ACS). He was started on dual antiplatelet therapy with <entity_1>aspirin</entity_1> and clopidogrel, along with <entity_2>high-dose atorvastatin</entity_2>, and a beta-blocker. A cardiology consultation was obtained, and the patient underwent coronary ang...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...ed with acute coronary syndrome (ACS). He was started on dual antiplatelet therapy with aspirin and <entity_1>clopidogrel</entity_1>, along with <entity_2>high-dose atorvastatin</entity_2>, and a beta-blocker. A cardiology consultation was obtained, and the patient underwent coronary ang...
#
# Extraction:
# /home/daviden1013/miniconda3/envs/NLP/lib/python3.11/site-packages/llm_ie/extractors.py:902: RuntimeWarning: Extracted relation type "No Relation", which is not in the return of possible_relation_types_func: ['Strength-Drug'].Following default, relation = "No Relation".
#   warnings.warn(f'Extracted relation type "{rel}", which is not in the return of possible_relation_types_func: {pos_rel_types}.'+ \
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...yndrome (ACS). He was started on dual antiplatelet therapy with aspirin and clopidogrel, along with <entity_1>high-dose atorvastatin</entity_1>, and a beta-blocker. A cardiology consultation was obtained, and the patient underwent coronary angiography, which revealed a 70% stenosis in the left anterior descending artery. A <entity_2>drug-eluting stent</entity_2> was placed successfully.
#
# Post-procedure, the patient was monitored in the coronary care unit. He r...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...rwent coronary angiography, which revealed a 70% stenosis in the left anterior descending artery. A <entity_1>drug-eluting stent</entity_1> was placed successfully.
#
# Post-procedure, the patient was monitored in the coronary care unit. He remained hemodynamically stable, with no recurrent chest pain. He was gradually advanced to a regular cardiac diet and was ambulating without difficulty by day three of hospitalization. Diabetes management was optimized with the addition of metformin, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_2>81 mg</entity_2> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinop...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_2>81 mg</entity_2> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinop...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_2>daily</entity_2>
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel <entity_2>75 mg</entity_2> daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformi...
#
# Extraction:
# /home/daviden1013/miniconda3/envs/NLP/lib/python3.11/site-packages/llm_ie/extractors.py:902: RuntimeWarning: Extracted relation type "No Relation", which is not in the return of possible_relation_types_func: ['Frequency-Drug'].Following default, relation = "No Relation".
#   warnings.warn(f'Extracted relation type "{rel}", which is not in the return of possible_relation_types_func: {pos_rel_types}.'+ \
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg <entity_2>daily</entity_2>
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin <entity_2>40 mg</entity_2> daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# ####...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg <entity_2>daily</entity_2>
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Disch...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol <entity_2>50 mg</entity_2> twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# J...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg <entity_2>twice daily</entity_2>
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was ...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ... difficulty by day three of hospitalization. Diabetes management was optimized with the addition of <entity_1>metformin</entity_1>, and his blood pressure was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> <entity_2>81 mg</entity_2> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinop...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg <entity_2>daily</entity_2>
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel <entity_2>75 mg</entity_2> daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformi...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg <entity_2>daily</entity_2>
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin <entity_2>40 mg</entity_2> daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# ####...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg <entity_2>daily</entity_2>
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Disch...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol <entity_2>50 mg</entity_2> twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# J...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg <entity_2>twice daily</entity_2>
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was ...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...was controlled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - <entity_1>Aspirin</entity_1> 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...rolled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_1>81 mg</entity_1> daily
# - <entity_2>Clopidogrel</entity_2> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Me...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...rolled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_1>81 mg</entity_1> daily
# - Clopidogrel 75 mg daily
# - <entity_2>Atorvastatin</entity_2> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...rolled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_1>81 mg</entity_1> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...rolled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_1>81 mg</entity_1> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...rolled with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin <entity_1>81 mg</entity_1> daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_1>daily</entity_1>
# - <entity_2>Clopidogrel</entity_2> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Me...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ... with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_1>daily</entity_1>
# - Clopidogrel 75 mg daily
# - <entity_2>Atorvastatin</entity_2> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_1>daily</entity_1>
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_1>daily</entity_1>
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ... with the continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg <entity_1>daily</entity_1>
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> <entity_2>75 mg</entity_2> daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformi...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg <entity_2>daily</entity_2>
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin <entity_2>40 mg</entity_2> daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# ####...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg <entity_2>daily</entity_2>
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Disch...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol <entity_2>50 mg</entity_2> twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# J...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg <entity_2>twice daily</entity_2>
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was ...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...e continuation of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - <entity_1>Clopidogrel</entity_1> 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...on of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel <entity_1>75 mg</entity_1> daily
# - <entity_2>Atorvastatin</entity_2> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...on of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel <entity_1>75 mg</entity_1> daily
# - Atorvastatin 40 mg daily
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...on of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel <entity_1>75 mg</entity_1> daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...on of his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel <entity_1>75 mg</entity_1> daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg <entity_1>daily</entity_1>
# - <entity_2>Atorvastatin</entity_2> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg <entity_1>daily</entity_1>
# - Atorvastatin 40 mg daily
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg <entity_1>daily</entity_1>
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...his antihypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg <entity_1>daily</entity_1>
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> <entity_2>40 mg</entity_2> daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# ####...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg <entity_2>daily</entity_2>
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Disch...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol <entity_2>50 mg</entity_2> twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# J...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol 50 mg <entity_2>twice daily</entity_2>
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was ...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...hypertensive regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - <entity_1>Atorvastatin</entity_1> 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin <entity_1>40 mg</entity_1> daily
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin <entity_1>40 mg</entity_1> daily
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...regimen.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin <entity_1>40 mg</entity_1> daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...n.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg <entity_1>daily</entity_1>
# - <entity_2>Metoprolol</entity_2> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instruct...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...n.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg <entity_1>daily</entity_1>
# - Metoprolol 50 mg twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...n.
#
# #### Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg <entity_1>daily</entity_1>
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> <entity_2>50 mg</entity_2> twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# J...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> 50 mg <entity_2>twice daily</entity_2>
# - Lisinopril 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was ...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> 50 mg twice daily
# - Lisinopril <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> 50 mg twice daily
# - Lisinopril 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ... Discharge Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - <entity_1>Metoprolol</entity_1> 50 mg twice daily
# - Lisinopril 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol <entity_1>50 mg</entity_1> twice daily
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...Medications
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol <entity_1>50 mg</entity_1> twice daily
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...tions
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg <entity_1>twice daily</entity_1>
# - <entity_2>Lisinopril</entity_2> 20 mg daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to fo...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...tions
# - Aspirin 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg <entity_1>twice daily</entity_1>
# - Lisinopril 20 mg daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...n 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_1>Lisinopril</entity_1> <entity_2>20 mg</entity_2> daily
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...n 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_1>Lisinopril</entity_1> 20 mg <entity_2>daily</entity_2>
# - Metformin 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}
#
#
#
# ROI text:
# ...n 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_1>Lisinopril</entity_1> 20 mg daily
# - Metformin <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...n 81 mg daily
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - <entity_1>Lisinopril</entity_1> 20 mg daily
# - Metformin 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...ly
# - Clopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril <entity_1>20 mg</entity_1> daily
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...lopidogrel 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg <entity_1>daily</entity_1>
# - <entity_2>Metformin</entity_2> 1000 mg twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy die...
#
# Extraction:
# {"RelationType": "No Relation"}
#
#
#
# ROI text:
# ...el 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_1>Metformin</entity_1> <entity_2>1000 mg</entity_2> twice daily
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engag...
#
# Extraction:
# {"RelationType": "Strength-Drug"}
#
#
#
# ROI text:
# ...el 75 mg daily
# - Atorvastatin 40 mg daily
# - Metoprolol 50 mg twice daily
# - Lisinopril 20 mg daily
# - <entity_1>Metformin</entity_1> 1000 mg <entity_2>twice daily</entity_2>
#
# #### Discharge Instructions
# John Doe was advised to follow a heart-healthy diet, engage in regular...
#
# Extraction:
# {"RelationType": "Frequency-Drug"}

# %% [markdown]
# The relation extractor ouptuts a list of relations as Dictionary of frame_1 id, frame_2 id and relation type.

# %%
print(relations)
# Out:
# [{'frame_1': '4', 'frame_2': '21', 'relation': 'Strength-Drug'}, {'frame_1': '4', 'frame_2': '22', 'relation': 'Frequency-Drug'}, {'frame_1': '5', 'frame_2': '6', 'relation': 'Strength-Drug'}, {'frame_1': '5', 'frame_2': '7', 'relation': 'Frequency-Drug'}, {'frame_1': '5', 'frame_2': '10', 'relation': 'Frequency-Drug'}, {'frame_1': '5', 'frame_2': '16', 'relation': 'Frequency-Drug'}, {'frame_1': '5', 'frame_2': '19', 'relation': 'Frequency-Drug'}, {'frame_1': '5', 'frame_2': '22', 'relation': 'Frequency-Drug'}, {'frame_1': '6', 'frame_2': '17', 'relation': 'Strength-Drug'}, {'frame_1': '7', 'frame_2': '8', 'relation': 'Frequency-Drug'}, {'frame_1': '7', 'frame_2': '17', 'relation': 'Frequency-Drug'}, {'frame_1': '8', 'frame_2': '9', 'relation': 'Strength-Drug'}, {'frame_1': '8', 'frame_2': '10', 'relation': 'Frequency-Drug'}, {'frame_1': '11', 'frame_2': '12', 'relation': 'Strength-Drug'}, {'frame_1': '11', 'frame_2': '13', 'relation': 'Frequency-Drug'}, {'frame_1': '13', 'frame_2': '14', 'relation': 'Frequency-Drug'}, {'frame_1': '14', 'frame_2': '15', 'relation': 'Strength-Drug'}, {'frame_1': '14', 'frame_2': '16', 'relation': 'Frequency-Drug'}, {'frame_1': '14', 'frame_2': '22', 'relation': 'Frequency-Drug'}, {'frame_1': '17', 'frame_2': '18', 'relation': 'Strength-Drug'}, {'frame_1': '17', 'frame_2': '19', 'relation': 'Frequency-Drug'}, {'frame_1': '20', 'frame_2': '21', 'relation': 'Strength-Drug'}, {'frame_1': '20', 'frame_2': '22', 'relation': 'Frequency-Drug'}]

# %% [markdown]
# Add the extracted relations to the document object. Validation is performed at the backend (e.g., check if all the frames in the relations exists).

# %%
doc.add_relations(relations)

# %% [markdown]
# Now the document has all the frames and relations.

# %%
print(doc)
# Out:
# LLMInformationExtractionDocument(doc_id: "Meidcal note"
# text: "### Discharge Summary Note
#
# **Patient Name:** John Doe
# **Medical Record Number:** 12345678
# **Dat...",
# frames: 24
# relations: 23

# %% [markdown]
# Optionally, we can save the document to file with ".llmie" extension. The extension is not enforced, but recommended.

# %%
# doc.save("<your_directory>/<your_filename>.llmie")

# %% [markdown]
# ### Conclusion
#
# In this demo, we performed NER with ```SentenceFrameExtractor``` and RE with ```MultiClassRelationExtractor```. The output is a document object that holds the frames of "Medication", "Strength", and "Frequency" and relations of "Strength-Drug" and "Frequency-Drug".
